# %% [markdown]
# ## Week 3 - Homework
#
# Jorge Vladimir Abrego Arevalo

# %% [markdown]
# ### Q1. Human-readable name
#
# > @task(retries=3, retry_delay_seconds=2, name="Read taxi data")

# %% [markdown]
# ### Q2. Cron

# %% [markdown]
# Let's create a new deploy
#
# > prefect deploy "Week 3/3.4/orchestrate.py:main_flow" -n taxi-hw -p zoompool
#
# And start the worker
#
# > prefect worker start -p zoompool
#
# In the Prefect UI, schedule flow with cron:
#
# <img src="images/cron-config.png" alt="Cron Configuration" />
#
# Clic on save, an we check the new configuration on Deployment edition:
#
# <img src="images/scheduling.png" alt="Deployment edit" />
#
# Then, we confirm the new scheduling at Flow option:
#
# <img src="images/flow-schedule.png" alt="Flow Scheduling" />

# %% [markdown]
# ### Q3. RMSE

# %% [markdown]
# Create a custom run an change training and test data
#
# <img src="images/custom-run.png" alt="Custom Run" />
#
# Once flow is finished, we look for it:
#
# <img src="images/custom-run-info.png" alt="Custom Run Info" />
#
# Clic on it and let's look for final RMSE
#
# <img src="images/final-rmse.png" alt="Final RMSE" />

# %% [markdown]
# ### Q1. Prepare the dataset
#
# What is the shape of the downloaded data? How many rows are there?
#
# <img src="../images/march_df.PNG" alt="Standard deviation of the predicted duration" />

# %% [markdown]
# ## Week 6 - Homework
#
# Jorge Vladimir Abrego Arevalo

# %% [markdown]
# ### Q1. Refactoring
#
# What is the shape of the downloaded data? How many rows are there?
#
# <img src="../images/march_df.PNG" alt="Standard deviation of the predicted duration" />

# %% [markdown]
# > docker build -t batch-ride-duration-prediction:v2 .
#
# > docker run -v $pwd/output:/output --rm batch-ride-duration-prediction:v2 2022 3

# %% [markdown]
# ### Q1. Prepare the dataset
#
# What is the shape of the downloaded data? How many rows are there?
#
# <img src="../images/march_df.PNG" alt="Standard deviation of the predicted duration" />
